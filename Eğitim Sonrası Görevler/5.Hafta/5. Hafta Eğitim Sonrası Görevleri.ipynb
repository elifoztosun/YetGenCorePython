# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
def hareket(vi,a,t,): # bunu çözmenin daha iyi yollarına bakılacak
    sonhiz= vi + a*t
    print(sonhiz)
hareket(30,2,3)
# Out:
# 36

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mukemmelsayi(sayi):
    top=0
    for i in range (1,sayi):
        top+=i 
        if top==sayi:
            print(f"{sayi} sayısı mükemmel sayıdır")

mukemmelsayi(28)
# Out:
# 28 sayısı mükemmel sayıdır

# %%
# 1den 1000 e kadar olan::::::
def mukemmel(sayi1,sayi2):
    isUnique=[]
    for num in range(sayi1,sayi2):
        top=0
        for i in range(1,num):
            if num % i==0:
                top+=i
        if top==num:
            isUnique.append(num)
    return isUnique

mukemmel(1,1000)
# Out:
# [6, 28, 496]

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
#????????????????????????????????????????????????
def iSpisagor()

# %%
# func seklinde olmasa napardım
dikUcgena=[]
dikUcgenb=[]
dikUcgenc=[]
for a in range(1,100):
    for b in range (1,100):
        for c in range(1,100):
            if (a**2) + (b**2)== c**2:
                dikUcgena.append(a)
                dikUcgenb.append(b)
                dikUcgenc.append(c)
print(dikUcgena)
print(dikUcgenb)
print(dikUcgenc)          #boyle oldu az çok buna benzer çıkacak bence cevap :'))
# Out:
# [3, 4, 5, 6, 7, 8, 8, 9, 9, 10, 11, 12, 12, 12, 12, 13, 14, 15, 15, 15, 16, 16, 16, 18, 18, 20, 20, 20, 21, 21, 21, 24, 24, 24, 24, 24, 24, 25, 27, 28, 28, 30, 30, 30, 32, 32, 33, 33, 35, 35, 36, 36, 36, 36, 39, 39, 40, 40, 40, 40, 42, 42, 44, 45, 45, 45, 48, 48, 48, 48, 48, 51, 52, 54, 55, 56, 56, 57, 60, 60, 60, 60, 60, 63, 63, 64, 65, 68, 70, 72, 72, 72, 72, 75, 76, 77, 80, 80, 84, 84]
# [4, 3, 12, 8, 24, 6, 15, 12, 40, 24, 60, 5, 9, 16, 35, 84, 48, 8, 20, 36, 12, 30, 63, 24, 80, 15, 21, 48, 20, 28, 72, 7, 10, 18, 32, 45, 70, 60, 36, 21, 45, 16, 40, 72, 24, 60, 44, 56, 12, 84, 15, 27, 48, 77, 52, 80, 9, 30, 42, 75, 40, 56, 33, 24, 28, 60, 14, 20, 36, 55, 64, 68, 39, 72, 48, 33, 42, 76, 11, 25, 32, 45, 63, 16, 60, 48, 72, 51, 24, 21, 30, 54, 65, 40, 57, 36, 18, 39, 13, 35]
# [5, 5, 13, 10, 25, 10, 17, 15, 41, 26, 61, 13, 15, 20, 37, 85, 50, 17, 25, 39, 20, 34, 65, 30, 82, 25, 29, 52, 29, 35, 75, 25, 26, 30, 40, 51, 74, 65, 45, 35, 53, 34, 50, 78, 40, 68, 55, 65, 37, 91, 39, 45, 60, 85, 65, 89, 41, 50, 58, 85, 58, 70, 55, 51, 53, 75, 50, 52, 60, 73, 80, 85, 65, 90, 73, 65, 70, 95, 61, 65, 68, 75, 87, 65, 87, 80, 97, 85, 74, 75, 78, 90, 97, 85, 95, 85, 82, 89, 85, 91]

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
def kackutu(h,a):
    kutusay= (h*a)/5
    kutu1= round(kutusay) 
    if kutusay> kutu1:
        kutu2= kutu1 + 1  
        print(f"gerekli kutu sayısı:{kutu2}")
    else:
        print(f"gerekli kutu sayısı:{kutu1}")

kackutu(3,10)
kackutu(4,7)
kackutu(8,4)
# Out:
# gerekli kutu sayısı:6
# gerekli kutu sayısı:6
# gerekli kutu sayısı:7

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
def harfsay(kelime):
    count= 0
    sesli="aeıioöuü"
    for i in kelime:
        if i in sesli:
            count+=1
    sessiz= len(kelime) - count
    print(f"sesli harf sayısı:{count}")
    print(f"sessiz harf sayısı:{sessiz}")
harfsay("ebru")
harfsay("python")
harfsay("bilgisayar")
# Out:
# sesli harf sayısı:2
# sessiz harf sayısı:2
# sesli harf sayısı:1
# sessiz harf sayısı:5
# sesli harf sayısı:4
# sessiz harf sayısı:6

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def findEvenNumbers(numbers=[]):
    even_numbers=[]
    for num in numbers:
        if num%2==0:
            even_numbers.append(num)
    print(even_numbers)
findEvenNumbers([2,43,3,7,9,34,14,12,13])
findEvenNumbers([23,22,24,25,76])
# Out:
# [2, 34, 14, 12]
# [22, 24, 76]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def sum(num):
    if num==1:
        return 1
    return num + sum(num-1)
sum(10)
sum(14)
# Out:
# 105
